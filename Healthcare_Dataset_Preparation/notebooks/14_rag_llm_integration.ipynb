# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[1] / "backend"))
from app.ai_engine.secure_rag import SecureRAGPipeline, LABEL_MAP
ROOT = Path.cwd().parents[1]
pipeline = SecureRAGPipeline(ROOT, review_policy="abstain")
# pipeline.load() downloads/loads BioBERT and FLAN-T5 if not cached.
assert LABEL_MAP == {0: "safe", 1: "malicious", 2: "phi", 3: "jailbreak", 4: "suspicious"}
# result = pipeline.answer("What is monkeypox?")
print("Security gate, Top-K evidence selection, FLAN-T5 grounding, and abstention are implemented.")
# Out:
# Security gate, Top-K evidence selection, FLAN-T5 grounding, and abstention are implemented.
