# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[1] / "backend"))
from app.ai_engine.behavioral import BehavioralAnomalyEngine
engine = BehavioralAnomalyEngine()
for _ in range(3):
    result = engine.evaluate("demo-session", 0.8, 0.2)
result
# Out:
# {"anomaly_score": 0.65, "is_anomalous": true, "event_count": 3, "high_risk_event_count": 3}
