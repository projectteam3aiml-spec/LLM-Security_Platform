# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[1] / "backend"))
from app.ai_engine.output_validator import OutputValidator
validator = OutputValidator()
synthetic_phi = "Patient Jane Doe MRN: AB123456 can be reached at jane@example.com."
validator.validate(synthetic_phi, "Patient information is confidential.")
# Out:
# {'validation_status': 'PHI_DETECTED', 'final_answer': 'The available information is insufficient to answer this question.'}
