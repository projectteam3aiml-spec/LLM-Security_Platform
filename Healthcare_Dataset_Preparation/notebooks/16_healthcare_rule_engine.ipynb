# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[1] / "backend"))
from app.ai_engine.healthcare_rules import HealthcareRuleEngine
engine = HealthcareRuleEngine()
samples = ["I have chest pain", "Please prescribe a dosage", "What are normal hydration tips?"]
results = {text: engine.evaluate(text) for text in samples}
results
# Out:
# {"I have chest pain": {"risk_score": 0.85, "action": "block"}, "Please prescribe a dosage": {"risk_score": 0.6, "action": "warn"}, "What are normal hydration tips?": {"risk_score": 0.0, "action": "allow"}}
