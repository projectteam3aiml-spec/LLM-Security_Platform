# %%
from pathlib import Path
import sys
sys.path.append(str(Path.cwd().parents[1] / "backend"))
from app.ai_engine.explainability import ExplainabilityEngine
engine = ExplainabilityEngine()
engine.explain({"category": "Suspicious Intent", "threat_score": .7}, {"max_similarity": .2}, [], {"anomaly_score": .0, "reasons": []}, {"risk_score": .6, "matched_rules": [{"rule_id": "prescription_request"}]})
# Out:
# {"method": "decision-factor attribution", "note": "SHAP-ready interface; model-level SHAP can be enabled with a compatible explainer."}
